# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os
os.environ['LANGSMITH_ENDPOINT']
# Out:
# 'https://api.smith.langchain.com'

# %%
base_url = "http://localhost:11434"
model = "luffy"
from langchain_ollama import ChatOllama
llm = ChatOllama(
    base_url=base_url,
    model = model,
    temperature = 0.8,
    num_predict = 256
)

# %%
llm
# Out:
# ChatOllama(model='luffy', num_predict=256, temperature=0.8, base_url='http://localhost:11434')

# %%
response = llm.invoke("Hi my name is Shyam. WHat is yours?")
response.content
# Out:
# '**Luffy:** "Hey! I\'m Luffy, the Pirate King! What\'s your name, Shyam? Oh, and don\'t worry about the \'M\' part—I\'m not mad, just *super* excited to meet someone who\'s not trying to steal my treasure or challenge me to a fight! So, what do you like doing? I\'m'
